# %% [markdown]
# LINEAR REGRESSION MODEL FOR DETERMINING HOUSE PRICES

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder # for scaling and encoding
from sklearn.model_selection import train_test_split

house = pd.read_csv('house_prices_practice.csv')
house
# Out:
#       Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  \
# 0      1            7       1560           0         1658       1969
# 1      2            4       2827           2         1319       2012
# 2      3            8       3920           0          841       2010
# 3      4            5       3044           0         1058       1998
# 4      5            7        801           1         2428       2020
# ..   ...          ...        ...         ...          ...        ...
# 295  296            1       3495           1         1792       1954
# 296  297            5       3438           3         1266       2003
# 297  298            6       1992           0         1148       1996
# 298  299            3       3722           1         1407       1998
# 299  300            9       1667           0          988       1958
#
#      FullBath  BedroomAbvGr  LotArea  SalePrice
# 0           2             1     8059     177106
# ...

# %%
house.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            300 non-null    int64
#  1   OverallQual   300 non-null    int64
#  2   GrLivArea     300 non-null    int64
#  3   GarageCars    300 non-null    int64
#  4   TotalBsmtSF   300 non-null    int64
#  5   YearBuilt     300 non-null    int64
#  6   FullBath      300 non-null    int64
#  7   BedroomAbvGr  300 non-null    int64
#  8   LotArea       300 non-null    int64
#  9   SalePrice     300 non-null    int64
# dtypes: int64(10)
# memory usage: 23.6 KB

# %%
house.head(10)
# Out:
#    Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  FullBath  \
# 0   1            7       1560           0         1658       1969         2
# 1   2            4       2827           2         1319       2012         3
# 2   3            8       3920           0          841       2010         1
# 3   4            5       3044           0         1058       1998         0
# 4   5            7        801           1         2428       2020         0
# 5   6           10        680           1         2480       1950         2
# 6   7            3       1106           2         1096       1962         1
# 7   8            7       3670           1          437       2000         2
# 8   9            8       1199           2         1653       2005         1
# 9  10            5       1492           1         2175       2011         1
#
#    BedroomAbvGr  LotArea  SalePrice
# 0             1     8059     177106
# 1             4    13530     301044
# ...

# %%
# CHECK IF THERE ARE ANY DUPLICATES OR NULL VALUES IN THE COLUMNS
house.duplicated().sum()
house.isnull().sum()

house.index.name='House_No.'
house.head(10)
# Out:
#            Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  \
# House_No.
# 0           1            7       1560           0         1658       1969
# 1           2            4       2827           2         1319       2012
# 2           3            8       3920           0          841       2010
# 3           4            5       3044           0         1058       1998
# 4           5            7        801           1         2428       2020
# 5           6           10        680           1         2480       1950
# 6           7            3       1106           2         1096       1962
# 7           8            7       3670           1          437       2000
# 8           9            8       1199           2         1653       2005
# 9          10            5       1492           1         2175       2011
#
#            FullBath  BedroomAbvGr  LotArea  SalePrice
# House_No.
# 0                 2             1     8059     177106
# ...

# %%
house.describe()
# Out:
#                Id  OverallQual    GrLivArea  GarageCars  TotalBsmtSF  \
# count  300.000000   300.000000   300.000000  300.000000   300.000000
# mean   150.500000     5.326667  2307.386667    1.330000  1468.796667
# std     86.746758     2.873001  1042.561303    1.109898   672.333705
# min      1.000000     1.000000   504.000000    0.000000   303.000000
# 25%     75.750000     3.000000  1392.250000    0.000000   903.000000
# 50%    150.500000     5.000000  2265.500000    1.000000  1502.000000
# 75%    225.250000     8.000000  3306.500000    2.000000  2129.500000
# max    300.000000    10.000000  3998.000000    3.000000  2492.000000
#
#          YearBuilt    FullBath  BedroomAbvGr       LotArea      SalePrice
# count   300.000000  300.000000    300.000000    300.000000     300.000000
# mean   1986.163333    1.523333      2.926667   8969.453333  252262.903333
# std      21.377089    1.131543      1.456604   3753.531132   74998.055214
# ...

# %% [markdown]
# ANALYTICAL VISUALIZATION FOR EACH FEATURE

# %%
fig = px.histogram(
    house,
    x='OverallQual',
    marginal='box',
    nbins=45,
    title='OVERALL QUALITY'
)
fig.update_layout(bargap=0)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['OverallQual'],
    bins=35,
    color='blue',
    edgecolor='black',
    rwidth=0.8
)

plt.title(' OVERALL QUALITY')
plt.xlabel('Overall quality')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='GrLivArea',
    marginal='box',
    color_discrete_sequence=['red'],
    nbins=45,
    title='GR LIV AREA'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['GrLivArea'],
    bins=35,
    color='red',
    edgecolor='black',
    rwidth=0.8
)

plt.title('GR LIV AREA')
plt.xlabel('GrLivArea')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='GarageCars',
    marginal='box',
    color_discrete_sequence=['green'],
    nbins=45,
    title='NO. OF GARAGE CARS'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['GarageCars'],
    bins=35,
    color='green',
    edgecolor='black',
    rwidth=0.8
)

plt.title('NO. OF GARAGE CARS')
plt.xlabel('GarageCars')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='TotalBsmtSF',
    marginal='box',
    color_discrete_sequence=['orange'],
    nbins=45,
    title='TotalBsmtSF'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['TotalBsmtSF'],
    bins=35,
    color='orange',
    edgecolor='black',
    rwidth=0.8
)

plt.title('TotalBsmtSF')
plt.xlabel('TotalBsmtSF')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='YearBuilt',
    marginal='box',
    color_discrete_sequence=['purple'],
    nbins=45,
    title='YEAR THE HOUSE WAS BUILT'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['YearBuilt'],
    bins=35,
    color='purple',
    edgecolor='black',
    rwidth=0.8
)

plt.title('YEAR THE HOUSE WAS BUILT')
plt.xlabel('TotalBsmtSF')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='FullBath',
    marginal='box',
    color_discrete_sequence=['crimson'],
    nbins=45,
    title='PRESENCE OF FULL WASHROOM ESSENTIALS'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['FullBath'],
    bins=35,
    color='crimson',
    edgecolor='black',
    rwidth=0.8
)

plt.title('PRESENCE OF FULL WASHROOM ESSENTIALS')
plt.xlabel('FullBath')
plt.ylabel('Frequency')

plt.show()

# %%
fig = px.histogram(
    house,
    x='BedroomAbvGr',
    marginal='box',
    color_discrete_sequence=['brown'],
    nbins=45,
    title='PRESENCE OF BEDROOM ABOVE GROUND'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['BedroomAbvGr'],
    bins=35,
    color='brown',
    edgecolor='black',
    rwidth=0.8
)

plt.title('PRESENCE OF BEDROOM ABOVE GROUND')
plt.xlabel('BedroomAbvGr')
plt.ylabel('Frequency')

plt.show()

# %%
house.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            300 non-null    int64
#  1   OverallQual   300 non-null    int64
#  2   GrLivArea     300 non-null    int64
#  3   GarageCars    300 non-null    int64
#  4   TotalBsmtSF   300 non-null    int64
#  5   YearBuilt     300 non-null    int64
#  6   FullBath      300 non-null    int64
#  7   BedroomAbvGr  300 non-null    int64
#  8   LotArea       300 non-null    int64
#  9   SalePrice     300 non-null    int64
# dtypes: int64(10)
# memory usage: 23.6 KB

# %%
fig = px.histogram(
    house,
    x='LotArea',
    marginal='box',
    color_discrete_sequence=['yellow'],
    nbins=45,
    title='SIZE OF THE LOT AREA'
)
fig.update_layout(bargap=0.2)
fig.show()

# USING PYPLOT
plt.figure(figsize=(10, 6))
plt.hist(
    house['LotArea'],
    bins=35,
    color='yellow',
    edgecolor='black',
    rwidth=0.8
)

plt.title('SIZE OF THE LOT AREA')
plt.xlabel('LotArea')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# IDENTIFICATION OF THE TARGET FEATURE -> SalePrice
#
# PLOTTING OF THE TARGET FEATURES AGAINST THE PREDICTOR FEATURES

# %%
# PLOTTING GRAPH OF SalePrice AGAINST OVERALL QUALITY

fig =px.violin(
    house,
    x='OverallQual',
    y='SalePrice',
    #opacity=0.8,
    title=' GRAPH OF SALE PRICE AGAINST OVERALL QUALITY'
)

fig.update_layout(bargap=0.5)
fig.show()


sns.scatterplot(x='OverallQual', y='SalePrice', data=house, s=8, alpha=0.8)
plt.xlabel('Previous Scores')
plt.ylabel('Performance Index')
plt.title('GRAPH OF SALE PRICE AGAINST OVERALL QUALITY')
plt.show()

# %%
# PLOTTING GRAPH OF SalePrice AGAINST OVERALL LIVING AREA

fig =px.scatter(
    house,
    x='GrLivArea',
    y='SalePrice',
    opacity=0.8,
    title=' GRAPH OF SALE PRICE AGAINST OVERALL LIVING AREA'
)

fig.update_layout(bargap=0.5)
fig.show()


sns.scatterplot(x='GrLivArea', y='SalePrice', data=house, s=12, alpha=0.8)
plt.xlabel('OVERALL LIVING AREA')
plt.ylabel('SALES PRICE')
plt.title('GRAPH OF SALE PRICE AGAINST OVERALL LIVING AREA')
plt.show()

# %%
house.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            300 non-null    int64
#  1   OverallQual   300 non-null    int64
#  2   GrLivArea     300 non-null    int64
#  3   GarageCars    300 non-null    int64
#  4   TotalBsmtSF   300 non-null    int64
#  5   YearBuilt     300 non-null    int64
#  6   FullBath      300 non-null    int64
#  7   BedroomAbvGr  300 non-null    int64
#  8   LotArea       300 non-null    int64
#  9   SalePrice     300 non-null    int64
# dtypes: int64(10)
# memory usage: 23.6 KB

# %% [markdown]
# MANUAL CONFIGURATION OF THE REGRESSION BEST FIT LINE
#
# LINEAR REGRESSION LINE -> Y = aX + b
#
#           where Y -> SalePrice
#                 a -> slope
#                 b -> intercept
#                 X -> Overall living area

# %%
def estimate_price(input, a, b):
    return a * input + b

a = 65
b = 100000
input = house['GrLivArea']
actual_target = house['SalePrice']
estimated_target = estimate_price(input, a, b)

#  USING SEABORN VERSION
plt.plot(input, estimated_target, 'r', alpha=0.8)
sns.scatterplot(x=input, y=actual_target, s=8, alpha=0.8)
plt.xlabel('GrLivArea')
plt.ylabel('SalePrice')
plt.title('GRAPH OF SALES PRICE AGAINST OVERALL LIVING AREA')
plt.legend(['Estimate', 'Actual'])
plt.show()

# USING PLOTLY

fig = go.Figure()   

# Actual data points
fig.add_trace(go.Scatter(
    x=input, y=actual_target,
    mode='markers',
    marker=dict(size=8, opacity=0.8, color='blue'),  # color moved into marker dict
    name='Actual'
))

# Estimated line
fig.add_trace(go.Scatter(
    x=input, y=estimated_target,
    mode='lines',
    line=dict(color='red'),
    opacity=0.8,
    name='Estimated'
))

fig.update_layout(
    title='GRAPH OF SALESPRICE AGAINST OVERALL LIVING AREA',
    xaxis_title='GrLivArea',
    yaxis_title='SalePrice'
)

fig.show()

# %% [markdown]
# LOSS / COST FUNCTION -> TO MEASURE NUMERICALLY HOW WELL THE LINE FITS THE POINTS
#
# LOWER RMSE -> BETTER FIT (predictions closer to actual values)
#  HIGHER RMSE -> WORSE FIT (predictions far from actual values)

# %%
#  MANUAL GENERATION OF THE LOSS COST FUNCTION

def rmse (actual_target, estimated_target):
    return np.sqrt(np.mean(np.square(actual_target-estimated_target)))

a = 65
b = 100000
estimated_target = estimate_price(input, a, b)
actual_target = house['SalePrice']

print("THE RMSE IS: ",rmse(actual_target, estimated_target))
print("COMPARE IT TO EITHER THE MEAN, MEDIAN, MIN AND MAX of the target")
# Out:
# THE RMSE IS:  51378.35557531336
# COMPARE IT TO EITHER THE MEAN, MEDIAN, MIN AND MAX of the target

# %%
house.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            300 non-null    int64
#  1   OverallQual   300 non-null    int64
#  2   GrLivArea     300 non-null    int64
#  3   GarageCars    300 non-null    int64
#  4   TotalBsmtSF   300 non-null    int64
#  5   YearBuilt     300 non-null    int64
#  6   FullBath      300 non-null    int64
#  7   BedroomAbvGr  300 non-null    int64
#  8   LotArea       300 non-null    int64
#  9   SalePrice     300 non-null    int64
# dtypes: int64(10)
# memory usage: 23.6 KB

# %% [markdown]
# CHECKING THE CORRELATIONS BETWEEN FEATURES

# %%
print("THE CORRELATION BETWEEN  SALES PRICE AND OverallQual IS: ", house['SalePrice'].corr(house['OverallQual']))

print("THE CORRELATION BETWEEN  SALES PRICE AND GrLivArea IS: ", house['SalePrice'].corr(house['GrLivArea']))

print("THE CORRELATION BETWEEN  SALES PRICE AND  GarageCars  IS: ", house['SalePrice'].corr(house['GarageCars']))
print("THE CORRELATION BETWEEN  SALES PRICE AND   TotalBsmtSF  IS: ", house['SalePrice'].corr(house['TotalBsmtSF']))
print("THE CORRELATION BETWEEN  SALES PRICE AND   YearBuilt  IS: ", house['SalePrice'].corr(house['YearBuilt']))
print("THE CORRELATION BETWEEN  SALES PRICE AND    FullBath  IS: ", house['SalePrice'].corr(house['FullBath']))
print("THE CORRELATION BETWEEN  SALES PRICE AND    BedroomAbvGr   IS: ", house['SalePrice'].corr(house['BedroomAbvGr']))
print("THE CORRELATION BETWEEN  SALES PRICE AND    LotArea   IS: ", house['SalePrice'].corr(house['LotArea']))
# Out:
# THE CORRELATION BETWEEN  SALES PRICE AND OverallQual IS:  0.35289944526669365
# THE CORRELATION BETWEEN  SALES PRICE AND GrLivArea IS:  0.7450945366200745
# THE CORRELATION BETWEEN  SALES PRICE AND  GarageCars  IS:  0.35132062827915633
# THE CORRELATION BETWEEN  SALES PRICE AND   TotalBsmtSF  IS:  0.25017763274445903
# THE CORRELATION BETWEEN  SALES PRICE AND   YearBuilt  IS:  0.22214237205464973
# THE CORRELATION BETWEEN  SALES PRICE AND    FullBath  IS:  0.27373100119765575
# THE CORRELATION BETWEEN  SALES PRICE AND    BedroomAbvGr   IS:  0.014113245035166725
# THE CORRELATION BETWEEN  SALES PRICE AND    LotArea   IS:  -0.038981895160028

# %%
# SETTING UP A CORRELATION MATRIX
matrix = house.corr()

plt.figure(figsize=(16, 12))  # increase width/height to fit all rows/columns
sns.heatmap(
    matrix,
    cmap='Reds',
    annot=True,
    fmt='.2f',              # rounds displayed values to 2 decimals, reduces clutter
    annot_kws={'size': 15}   # shrinks number font so it fits in each cell
)
plt.title("CORRELATION MATRIX FOR HOUSE PRICES")
plt.xticks(rotation=45, ha='right')  # tilts x labels so long column names don't overlap
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
